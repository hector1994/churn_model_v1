# %% [markdown]
# <a href="https://colab.research.google.com/github/hector1994/churn_model_v1/blob/master/SPRINT_7_TT_DA_97_Let's_get_better.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📤 __IMPORTS PRINCIPALES Y CONFIGURACIONES GLOBALES__⚙️
# ---

# %%
#IMPORTS PRINCIPALES:
import pandas  as pd               #LECTURA, MANEJO Y TRANSFORMACIÓN DE DATAFRAMES.
import numpy   as np               #FUNCIONES MATEMÁTICAS RELEVANTES.
import matplotlib.pyplot as plt    #GRÁFICOS.
import seaborn as sns              #GRÁFICOS PRETTY.


#CONFIGURACIONES GLOBALES:
import warnings                                                #MANEJO DE WARNINGS - ADVERTENCIAS
warnings.simplefilter(action='ignore', category=FutureWarning) #QUITAR WARNINGS MOLESTOS
pd.set_option('display.max_columns', None)                     #ELIMINA LIMITES DE PANDAS PARA MOSTRAR COLUMNAS
pd.set_option('display.max_rows', None)                        #ELIMINA LIMITES DE PANDAS PARA MOSTRAR FILAS
pd.set_option('display.max_colwidth', None)                    #AUTOAJUSTA ANCHO DE COLUMNAS

# %% [markdown]
# ## 🗂️__LEYENDO DATA  + GENERAR PANDAS DATAFRAME__📊
# ---

# %%
#CARGANDO DATA: ESTE DATASET SE ECUENTRA ALMACENADO EN REPOSITORIO DE GITHUB.
ruta_tabla = "https://media.githubusercontent.com/media/hector1994/e_commerce_funnel_data_generator/refs/heads/master/sales_data_dirty_sp7_data.csv"

df_raw     = pd.read_csv(ruta_tabla)  #DATA SIN PROCESAR.
df_raw.head(3)                        #MUESTRAS LOS PRIMEROS 5 REGISTROS DEL DATAFRAME - df.tail()
# Out:
#                                order_id  order_date  customer_id  \
# 0  98c01d39-0be7-4ee0-9ecf-50a50b63159a  2024-06-12       250414
# 1  715759ca-06c2-4b36-b86f-177b6b154a7a  2025-05-29       269884
# 2  46e91d25-94ff-4eca-9fe7-7d7cb4683429  2025-10-04        54582
#
#      customer_name                     customer_email customer_country  \
# 0      Jorge Pérez     jorge.pérez_250414@example.com            Chile
# 1    Isabel Castro   isabel.castro_269884@example.com         Colombia
# 2  Francisco Rojas  francisco.rojas_54582@example.com        Argentina
#
#   country_code  customer_city       customer_address product_id  \
# 0          CHL       Rancagua   5054 Calle Los Pinos       P012
# 1          COL       Medellín  5375 Calle Los Alamos       P015
# 2          ARG  Mar del Plata   3777 Calle Los Pinos       P008
#
#                    product_name product_category  quantity  price_per_unit  \
# 0   Headphones NoiseCancelling       Electronics         1           250.0
# 1                    Hair Dryer             Home         1            35.0
# 2                  Office Chair        Furniture         1           200.0
#
#    total_weight  shipping_cost  total_amount_gross  discount_amount  \
# 0           0.3           5.45               250.0              0.0
# 1           0.6           5.90                35.0              3.5
# 2          15.0          27.50               200.0             10.0
#
#    tax_amount  final_total_amount payment_method shipping_status
# 0      47.500             302.950         PayPal       Delivered
# 1       5.985              43.385    Credit Card         Shipped
# 2      36.100             253.600         PayPal         Shipped

# %% [markdown]
# ## 🗺️__COMENCEMOS A EXPLORAR__📚
# ---

# %%
#HACEMOS UNA COPIA PROFUNDA.
df_work = df_raw.copy(deep = True)

# %%
df_work.head()
# Out:
#                                order_id  order_date  customer_id  \
# 0  98c01d39-0be7-4ee0-9ecf-50a50b63159a  2024-06-12       250414
# 1  715759ca-06c2-4b36-b86f-177b6b154a7a  2025-05-29       269884
# 2  46e91d25-94ff-4eca-9fe7-7d7cb4683429  2025-10-04        54582
# 3  df2478f3-f34f-4f18-82eb-86727241b153  2024-11-19       194401
# 4  e6a850d8-d658-46fb-9c94-4f99af54a596  2026-01-07       104597
#
#      customer_name                     customer_email customer_country  \
# 0      Jorge Pérez     jorge.pérez_250414@example.com            Chile
# 1    Isabel Castro   isabel.castro_269884@example.com         Colombia
# 2  Francisco Rojas  francisco.rojas_54582@example.com        Argentina
# 3   Carlos Ramírez  carlos.ramírez_194401@example.com             Perú
# 4     Pedro García    pedro.garcía_104597@example.com        Argentina
#
#   country_code  customer_city       customer_address product_id  \
# 0          CHL       Rancagua   5054 Calle Los Pinos       P012
# 1          COL       Medellín  5375 Calle Los Alamos       P015
# 2          ARG  Mar del Plata   3777 Calle Los Pinos       P008
# 3          PER          Piura  2115 Calle Secundaria       P015
# 4          ARG        Córdoba  6181 Calle Secundaria       P002
#
#                    product_name product_category  quantity  price_per_unit  \
# 0   Headphones NoiseCancelling       Electronics         1           250.0
# 1                    Hair Dryer             Home         1            35.0
# 2                  Office Chair        Furniture         1           200.0
# 3                    Hair Dryer             Home         1             NaN
# 4                  Smartphone X      Electronics         1           800.0
#
#    total_weight  shipping_cost  total_amount_gross  discount_amount  \
# 0           0.3           5.45               250.0              0.0
# 1           0.6           5.90                35.0              3.5
# 2          15.0          27.50               200.0             10.0
# 3           0.6           5.90                35.0              0.0
# 4           0.2           5.30               800.0             40.0
#
#    tax_amount  final_total_amount payment_method shipping_status
# 0      47.500             302.950         PayPal       Delivered
# 1       5.985              43.385    Credit Card         Shipped
# 2      36.100             253.600         PayPal         Shipped
# 3       6.650              47.550         PayPal       Delivered
# 4     144.400             909.700  Bank Transfer       Delivered

# %% [markdown]
# ## 🧹 __LIMPIEMOS Y ESTANDARICEMOS UN "POCO" 🫧🧺__
# ---

# %%
#REVISEMOS LAS COLUMNAS CATEGÓRICAS BUSCANDO ESTANDARIZAR.

# %%
#MANEJO DE VALORES NULOS.

# %%
#DUPLICADOS
df_work[df_work.duplicated(keep = False)].sort_values(by ='customer_id', ascending = False).head()
# Out:
#                                      order_id  order_date  customer_id  \
# 67474    95174639-d54c-4d9b-9390-a695a25e5130  2024-03-08       400996
# 2000982  95174639-d54c-4d9b-9390-a695a25e5130  2024-03-08       400996
# 2000462  9e0ec4b1-787e-4e3c-8230-82e50e23a50f  2024-09-08       400960
# 216121   9e0ec4b1-787e-4e3c-8230-82e50e23a50f  2024-09-08       400960
# 1649636  5fe7105f-5dc4-4740-bcc4-0c66724f5413  2024-06-12       400907
#
#             customer_name                       customer_email  \
# 67474     Benjamín García   benjamín.garcía_400996@example.com
# 2000982   Benjamín García   benjamín.garcía_400996@example.com
# 2000462  Valentina Torres  valentina.torres_400960@example.com
# 216121   Valentina Torres  valentina.torres_400960@example.com
# 1649636      Isabel Muñoz      isabel.muñoz_400907@example.com
#
#         customer_country country_code  customer_city  customer_address  \
# 67474           Colombia          COL      Cartagena    1344 Calle Sur
# 2000982         Colombia          COL      Cartagena    1344 Calle Sur
# 2000462        Argentina          ARG  Mar del Plata   6077 Calle Este
# 216121         Argentina          ARG  Mar del Plata   6077 Calle Este
# 1649636           México          MEX      Monterrey  3412 Calle Oeste
#
#         product_id    product_name product_category  quantity  price_per_unit  \
# 67474         P008    Office Chair        Furniture         3           200.0
# 2000982       P008    Office Chair        Furniture         3           200.0
# 2000462       P019        Sneakers          Fashion         1            85.0
# 216121        P019        Sneakers          Fashion         1            85.0
# 1649636       P014  Microwave Oven             Home         1           150.0
#
#          total_weight  shipping_cost  total_amount_gross  discount_amount  \
# 67474            45.0          72.50               600.0             30.0
# 2000982          45.0          72.50               600.0             30.0
# 2000462           0.7           6.05                85.0              0.0
# 216121            0.7           6.05                85.0              0.0
# 1649636          10.0          20.00               150.0             15.0
#
#          tax_amount  final_total_amount payment_method shipping_status
# 67474        108.30              750.80     Debit Card       Delivered
# 2000982      108.30              750.80     Debit Card       Delivered
# 2000462       16.15              107.20     Debit Card         Shipped
# 216121        16.15              107.20     Debit Card         Shipped
# 1649636       25.65              180.65     Debit Card      Processing

# %%
df_work.drop_duplicates(inplace = True)
# Out:
# /tmp/ipykernel_24738/3962262628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_work.drop_duplicates(inplace = True)

# %%
df_work[df_work.duplicated(keep = False)].sort_values(by ='customer_id', ascending = False).head()
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, customer_id, customer_name, customer_email, customer_country, country_code, customer_city, customer_address, product_id, product_name, product_category, quantity, price_per_unit, total_weight, shipping_cost, total_amount_gross, discount_amount, tax_amount, final_total_amount, payment_method, shipping_status]
# Index: []

# %%
df_work['order_date'] = pd.to_datetime(df_work['order_date'], format = '%Y-%m-%d')
# Out:
# /tmp/ipykernel_24738/1436791924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_work['order_date'] = pd.to_datetime(df_work['order_date'], format = '%Y-%m-%d')

# %%
df_work.head()
# Out:
#                                order_id order_date  customer_id  \
# 0  98c01d39-0be7-4ee0-9ecf-50a50b63159a 2024-06-12       250414
# 1  715759ca-06c2-4b36-b86f-177b6b154a7a 2025-05-29       269884
# 2  46e91d25-94ff-4eca-9fe7-7d7cb4683429 2025-10-04        54582
# 3  df2478f3-f34f-4f18-82eb-86727241b153 2024-11-19       194401
# 4  e6a850d8-d658-46fb-9c94-4f99af54a596 2026-01-07       104597
#
#      customer_name                     customer_email customer_country  \
# 0      Jorge Pérez     jorge.pérez_250414@example.com            Chile
# 1    Isabel Castro   isabel.castro_269884@example.com         Colombia
# 2  Francisco Rojas  francisco.rojas_54582@example.com        Argentina
# 3   Carlos Ramírez  carlos.ramírez_194401@example.com             Perú
# 4     Pedro García    pedro.garcía_104597@example.com        Argentina
#
#   country_code  customer_city       customer_address product_id  \
# 0          CHL       Rancagua   5054 Calle Los Pinos       P012
# 1          COL       Medellín  5375 Calle Los Alamos       P015
# 2          ARG  Mar del Plata   3777 Calle Los Pinos       P008
# 3          PER          Piura  2115 Calle Secundaria       P015
# 4          ARG        Córdoba  6181 Calle Secundaria       P002
#
#                    product_name product_category  quantity  price_per_unit  \
# 0   Headphones NoiseCancelling       Electronics         1           250.0
# 1                    Hair Dryer             Home         1            35.0
# 2                  Office Chair        Furniture         1           200.0
# 3                    Hair Dryer             Home         1             NaN
# 4                  Smartphone X      Electronics         1           800.0
#
#    total_weight  shipping_cost  total_amount_gross  discount_amount  \
# 0           0.3           5.45               250.0              0.0
# 1           0.6           5.90                35.0              3.5
# 2          15.0          27.50               200.0             10.0
# 3           0.6           5.90                35.0              0.0
# 4           0.2           5.30               800.0             40.0
#
#    tax_amount  final_total_amount payment_method shipping_status
# 0      47.500             302.950         PayPal       Delivered
# 1       5.985              43.385    Credit Card         Shipped
# 2      36.100             253.600         PayPal         Shipped
# 3       6.650              47.550         PayPal       Delivered
# 4     144.400             909.700  Bank Transfer       Delivered

# %%
#VERIFICAR INCONSISTENCIAS?

# %%
#GUARDAR DATA LIMPIA.

# %%
#BONUS EXTRA: GENERAR LISTAS DETECTANDO AUTOMÁTICA EL TIPO DE DATO CON EL MÉTODO select_dtypes()
cols_numericas   = df_work.select_dtypes(include=['number']).columns.tolist()
cols_categoricas = df_work.select_dtypes(include=['object']).columns.tolist()

# %%
df_work[cols_categoricas].head()
# Out:
#                                order_id  order_date    customer_name  \
# 0  98c01d39-0be7-4ee0-9ecf-50a50b63159a  2024-06-12      Jorge Pérez
# 1  715759ca-06c2-4b36-b86f-177b6b154a7a  2025-05-29    Isabel Castro
# 2  46e91d25-94ff-4eca-9fe7-7d7cb4683429  2025-10-04  Francisco Rojas
# 3  df2478f3-f34f-4f18-82eb-86727241b153  2024-11-19   Carlos Ramírez
# 4  e6a850d8-d658-46fb-9c94-4f99af54a596  2026-01-07     Pedro García
#
#                       customer_email customer_country country_code  \
# 0     jorge.pérez_250414@example.com            Chile          CHL
# 1   isabel.castro_269884@example.com         Colombia          COL
# 2  francisco.rojas_54582@example.com        Argentina          ARG
# 3  carlos.ramírez_194401@example.com             Perú          PER
# 4    pedro.garcía_104597@example.com        Argentina          ARG
#
#    customer_city       customer_address product_id  \
# 0       Rancagua   5054 Calle Los Pinos       P012
# 1       Medellín  5375 Calle Los Alamos       P015
# 2  Mar del Plata   3777 Calle Los Pinos       P008
# 3          Piura  2115 Calle Secundaria       P015
# 4        Córdoba  6181 Calle Secundaria       P002
#
#                    product_name product_category payment_method  \
# 0   Headphones NoiseCancelling       Electronics         PayPal
# 1                    Hair Dryer             Home    Credit Card
# 2                  Office Chair        Furniture         PayPal
# 3                    Hair Dryer             Home         PayPal
# 4                  Smartphone X      Electronics  Bank Transfer
#
#   shipping_status
# 0       Delivered
# 1         Shipped
# 2         Shipped
# 3       Delivered
# 4       Delivered

# %%
#VEAMOS LAS LISTAS CON LOS NOMBRES DE COLUMNAS DE CADA TIPO: ESTO ES ÚTIL PARA DARLE EL TRATAMIENTO CORRESPONDIENTE A CADA TIPO DE DATO.
print(f"- Columnas numéricas   : {cols_numericas}")
print(f"- Columnas categóricas : {cols_categoricas}")
# Out:
# - Columnas numéricas   : ['customer_id', 'quantity', 'price_per_unit', 'total_weight', 'shipping_cost', 'total_amount_gross', 'discount_amount', 'tax_amount', 'final_total_amount']
# - Columnas categóricas : ['order_id', 'order_date', 'customer_name', 'customer_email', 'customer_country', 'country_code', 'customer_city', 'customer_address', 'product_id', 'product_name', 'product_category', 'payment_method', 'shipping_status']

# %% [markdown]
# ## 🚩 __CLASIFICACIÓN DE VALORES NULOS <code>NaN</code>__ 👽
# ---

# %% [markdown]
# * __MCAR (MISSING COMPLETLY AT RANDOM):__ Cada registro que es nulo lo hace sin nungún patron específico. Es decir, cualquiera de los registros tiene la misma chance de estar vacío. RECOMENDACIÓN: ELIMINAR O IMPUTAR (MEDIA O LA MEDIANA)
#
# * __MAR (MISSING AT RANDOM):__ Hay valores nulos, pero estos se relacionan con otra columna específica. EJ: Hay valores nulos, pero estos se asocian a una o varias columnas.
#
# * __MNAR (MISSING AT NO RANDOM):__ El valor no está o aparece nulo, pero no es al azar. Por ejemplo: Persona de áreas ricas de la ciudad, no dan su nombre por privacidad, por lo que la coluna user_name, suele tener nulos.

# %%
df_work['shipping_status'].isna().groupby(df_work['customer_country']).mean().sort_values(ascending = False)
# Out:
# customer_country
# Colombia     0.100464
# México       0.100453
# Chile        0.099923
# Brasil       0.099819
# Uruguay      0.099718
# Argentina    0.099698
# Ecuador      0.099649
# Perú         0.099516
# Name: shipping_status, dtype: float64

# %%
df_work['order_date'] = df_work['order_date'].astype('datetime64[ns]')

# %%
df_work = df_raw.dropna(subset = ['shipping_status'])

# %%
df_work.head()
# Out:
#                                order_id  order_date  customer_id  \
# 0  98c01d39-0be7-4ee0-9ecf-50a50b63159a  2024-06-12       250414
# 1  715759ca-06c2-4b36-b86f-177b6b154a7a  2025-05-29       269884
# 2  46e91d25-94ff-4eca-9fe7-7d7cb4683429  2025-10-04        54582
# 3  df2478f3-f34f-4f18-82eb-86727241b153  2024-11-19       194401
# 4  e6a850d8-d658-46fb-9c94-4f99af54a596  2026-01-07       104597
#
#      customer_name                     customer_email customer_country  \
# 0      Jorge Pérez     jorge.pérez_250414@example.com            Chile
# 1    Isabel Castro   isabel.castro_269884@example.com         Colombia
# 2  Francisco Rojas  francisco.rojas_54582@example.com        Argentina
# 3   Carlos Ramírez  carlos.ramírez_194401@example.com             Perú
# 4     Pedro García    pedro.garcía_104597@example.com        Argentina
#
#   country_code  customer_city       customer_address product_id  \
# 0          CHL       Rancagua   5054 Calle Los Pinos       P012
# 1          COL       Medellín  5375 Calle Los Alamos       P015
# 2          ARG  Mar del Plata   3777 Calle Los Pinos       P008
# 3          PER          Piura  2115 Calle Secundaria       P015
# 4          ARG        Córdoba  6181 Calle Secundaria       P002
#
#                    product_name product_category  quantity  price_per_unit  \
# 0   Headphones NoiseCancelling       Electronics         1           250.0
# 1                    Hair Dryer             Home         1            35.0
# 2                  Office Chair        Furniture         1           200.0
# 3                    Hair Dryer             Home         1             NaN
# 4                  Smartphone X      Electronics         1           800.0
#
#    total_weight  shipping_cost  total_amount_gross  discount_amount  \
# 0           0.3           5.45               250.0              0.0
# 1           0.6           5.90                35.0              3.5
# 2          15.0          27.50               200.0             10.0
# 3           0.6           5.90                35.0              0.0
# 4           0.2           5.30               800.0             40.0
#
#    tax_amount  final_total_amount payment_method shipping_status
# 0      47.500             302.950         PayPal       Delivered
# 1       5.985              43.385    Credit Card         Shipped
# 2      36.100             253.600         PayPal         Shipped
# 3       6.650              47.550         PayPal       Delivered
# 4     144.400             909.700  Bank Transfer       Delivered

# %% [markdown]
# ## __♻️ Funciones en Python 🚀__

# %% [markdown]
# Las funciones son una metedología de generación de un esquema general de un proceso repetitivo en python. Se caracateriza al igual que cualquier función por tener entrada - proceso - salida.
